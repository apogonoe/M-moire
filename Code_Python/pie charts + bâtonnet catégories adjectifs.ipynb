# %%
import pandas as pd
import numpy as np
import math
import distance
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from matplotlib.patches import ConnectionPatch
# %matplotlib inline

# %%
df1 = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/800-849 (copie).csv')
df2 = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/850-899 (copie).csv')
df3 = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/900-949 (copie).csv')
df4 = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/950-999 (copie).csv')
df5 = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/1000-1049 (copie).csv')
df6 = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/1050-1099 (copie).csv')
df7 = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/1100-1149 (copie).csv')
df8 = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/1150-1199 (copie).csv')
df9 = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/1200-1249 (copie).csv')
df10 = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/1250-1299 (copie).csv')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
fig.subplots_adjust(wspace=0)

overall_ratios = proportion
labels = ['1', '2', '3','4','5']

explode = [0.5, 0, 0]
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels,wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' })

age_ratios = liste_1
age_labels = liste_2
bottom = 1
width = .2

for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')
    

ax2.set_title('Lemmas')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 3 * width, 3 * width)    

theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)


x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)

plt.show()

# %%
df2 = df2.sort_values(by=['catégorie'])
lol = df2[df2['catégorie'] == 3]
lol['proportion'] = lol['Occurrences']/lol['Occurrences'].sum()
liste_prop = lol['proportion'].tolist()
proportion
# Out:
# /tmp/ipykernel_101628/3826971867.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lol['proportion'] = lol['Occurrences']/lol['Occurrences'].sum()
# [0.38095238095238093,
#  0.3557422969187675,
#  0.16806722689075632,
#  0.0,
#  0.09523809523809523]

# %%
liste_nom = []
for i in range(len(df1)):
    if df2['catégorie'][i] == 1:
        liste_nom.append(df2['lemma'][i])
liste_nom
# Out:
# ['iustus', 'augustus1', 'sanctus1', 'diuinus', 'ecclesiasticus1']

# %%
df_vide['catégorie'] = [1,2,3,4,5]
df_vide['Occurrences'] = [x,y,z,a,b]
df_vide['proportion'] = df1_vide['Occurrences']/df1_vide['Occurrences'].sum()
proportion = df1_vide['proportion'].tolist()

# %%
def pie_chart_1(path):
    
    df = pd.read_csv(path)
    df.pop('Unnamed: 0')
    df = df.dropna().reset_index()
    df.pop('index')

    df_vide = pd.DataFrame(columns=['catégorie','Occurrences'])
    
    x = 0
    y = 0
    z = 0
    a = 0
    b = 0
    for i in range(len(df)):
        if df['catégorie'][i] == 1:
            x += df['Occurrences'][i]
        if df['catégorie'][i] == 2:
            y += df['Occurrences'][i]
        if df['catégorie'][i] == 3:
            z += df['Occurrences'][i]
        if df['catégorie'][i] == 4:
            a += df['Occurrences'][i]
        if df['catégorie'][i] == 5:
            b += df['Occurrences'][i]
    
    df_vide['catégorie'] = [1,2,3,4,5]
    df_vide['Occurrences'] = [x,y,z,a,b]
    df_vide['proportion'] = df_vide['Occurrences']/df_vide['Occurrences'].sum()
    
    proportion = df_vide['proportion'].tolist()
    
    df = df.sort_values(by=['catégorie'])
    lol = df[df['catégorie'] == 1]
    lol['proportion'] = lol['Occurrences']/lol['Occurrences'].sum()
    liste_prop = lol['proportion'].tolist()
    
    liste_nom = []
    for i in range(len(df)):
        if df['catégorie'][i] == 1:
            liste_nom.append(df['lemma'][i])
    
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
    fig.subplots_adjust(wspace=0)

    overall_ratios = proportion
    labels = ['1', '2','3','4','5']

    
    colors=['turquoise','teal','lightgreen','aqua','aquamarine']
    explode = [0.5, 0, 0]
    angle = -180 * overall_ratios[0]
    wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels,wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' },colors=colors)

    age_ratios = liste_prop
    age_labels = liste_nom
    bottom = 1
    width = .2

    for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
        bottom -= height
        bc = ax2.bar(0, height, width, bottom=bottom, color='turquoise', label=label,
                 alpha=0.1 + 0.1 * j)
        ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')
    

    ax2.set_title(1)
    ax2.legend()
    ax2.axis('off')
    ax2.set_xlim(- 3 * width, 3 * width)    

    theta1, theta2 = wedges[0].theta1, wedges[0].theta2
    center, r = wedges[0].center, wedges[0].r
    bar_height = sum(age_ratios)

    x = r * np.cos(np.pi / 180 * theta2) + center[0]
    y = r * np.sin(np.pi / 180 * theta2) + center[1]
    con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)


    x = r * np.cos(np.pi / 180 * theta1) + center[0]
    y = r * np.sin(np.pi / 180 * theta1) + center[1]
    con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
    
    plt.title("Pie chart des lemmes de l'élément 1")

    plt.savefig("Pie_chart_lemmes_1.png")
    
    
    """"""
    
    df = df.sort_values(by=['catégorie'])
    lol = df[df['catégorie'] == 2]
    lol['proportion'] = lol['Occurrences']/lol['Occurrences'].sum()
    liste_prop = lol['proportion'].tolist()
    
    liste_nom = []
    for i in range(len(df)):
        if df['catégorie'][i] == 2:
            liste_nom.append(df['lemma'][i])
    
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
    fig.subplots_adjust(wspace=0)

    overall_ratios = proportion
    labels = ['1', '2','3','4','5']

    
    colors=['turquoise','teal','lightgreen','aqua','aquamarine']
    explode = [0.5, 0, 0]
    angle = -180 * overall_ratios[0]
    wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels,wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' },colors=colors)

    age_ratios = liste_prop
    age_labels = liste_nom
    bottom = 1
    width = .2

    for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
        bottom -= height
        bc = ax2.bar(0, height, width, bottom=bottom, color='teal', label=label,
                 alpha=0.1 + 0.1 * j)
        ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')
    

    ax2.set_title(2)
    ax2.legend()
    ax2.axis('off')
    ax2.set_xlim(- 3 * width, 3 * width)    

    theta1, theta2 = wedges[0].theta1, wedges[0].theta2
    center, r = wedges[0].center, wedges[0].r
    bar_height = sum(age_ratios)

    x = r * np.cos(np.pi / 180 * theta2) + center[0]
    y = r * np.sin(np.pi / 180 * theta2) + center[1]
    con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)


    x = r * np.cos(np.pi / 180 * theta1) + center[0]
    y = r * np.sin(np.pi / 180 * theta1) + center[1]
    con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
    
    plt.title("Pie chart des lemmes de l'élément 2")

    plt.savefig("Pie_chart_lemmes_2.png")
    
    """"""
    
    df = df.sort_values(by=['catégorie'])
    lol = df[df['catégorie'] == 3]
    lol['proportion'] = lol['Occurrences']/lol['Occurrences'].sum()
    liste_prop = lol['proportion'].tolist()
    
    liste_nom = []
    for i in range(len(df)):
        if df['catégorie'][i] == 3:
            liste_nom.append(df['lemma'][i])
    
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
    fig.subplots_adjust(wspace=0)

    overall_ratios = proportion
    labels = ['1', '2','3','4','5']

    
    colors=['turquoise','teal','lightgreen','aqua','aquamarine']
    explode = [0.5, 0, 0]
    angle = -180 * overall_ratios[0]
    wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels,wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' },colors=colors)

    age_ratios = liste_prop
    age_labels = liste_nom
    bottom = 1
    width = .2

    for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
        bottom -= height
        bc = ax2.bar(0, height, width, bottom=bottom, color='lightgreen', label=label,
                 alpha=0.1 + 0.1 * j)
        ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')
    

    ax2.set_title(3)
    ax2.legend()
    ax2.axis('off')
    ax2.set_xlim(- 3 * width, 3 * width)    

    theta1, theta2 = wedges[0].theta1, wedges[0].theta2
    center, r = wedges[0].center, wedges[0].r
    bar_height = sum(age_ratios)

    x = r * np.cos(np.pi / 180 * theta2) + center[0]
    y = r * np.sin(np.pi / 180 * theta2) + center[1]
    con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)


    x = r * np.cos(np.pi / 180 * theta1) + center[0]
    y = r * np.sin(np.pi / 180 * theta1) + center[1]
    con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
    
    plt.title("Pie chart des lemmes de l'élément 3")

    plt.savefig("Pie_chart_lemmes_3.png")
    
    """"""
    
    df = df.sort_values(by=['catégorie'])
    lol = df[df['catégorie'] == 4]
    lol['proportion'] = lol['Occurrences']/lol['Occurrences'].sum()
    liste_prop = lol['proportion'].tolist()
    
    liste_nom = []
    for i in range(len(df)):
        if df['catégorie'][i] == 4:
            liste_nom.append(df['lemma'][i])
    
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
    fig.subplots_adjust(wspace=0)

    overall_ratios = proportion
    labels = ['1', '2','3','4','5']

    
    colors=['turquoise','teal','lightgreen','aqua','aquamarine']
    explode = [0.5, 0, 0]
    angle = -180 * overall_ratios[0]
    wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels,wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' },colors=colors)

    age_ratios = liste_prop
    age_labels = liste_nom
    bottom = 1
    width = .2

    for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
        bottom -= height
        bc = ax2.bar(0, height, width, bottom=bottom, color='aqua', label=label,
                 alpha=0.1 + 0.1 * j)
        ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')
    

    ax2.set_title(4)
    ax2.legend()
    ax2.axis('off')
    ax2.set_xlim(- 3 * width, 3 * width)    

    theta1, theta2 = wedges[0].theta1, wedges[0].theta2
    center, r = wedges[0].center, wedges[0].r
    bar_height = sum(age_ratios)

    x = r * np.cos(np.pi / 180 * theta2) + center[0]
    y = r * np.sin(np.pi / 180 * theta2) + center[1]
    con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)


    x = r * np.cos(np.pi / 180 * theta1) + center[0]
    y = r * np.sin(np.pi / 180 * theta1) + center[1]
    con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
    
    plt.title("Pie chart des lemmes de l'élément 4")

    plt.savefig("Pie_chart_lemmes_4.png")
    
    """"""
    
    df = df.sort_values(by=['catégorie'])
    lol = df[df['catégorie'] == 5]
    lol['proportion'] = lol['Occurrences']/lol['Occurrences'].sum()
    liste_prop = lol['proportion'].tolist()
    
    liste_nom = []
    for i in range(len(df)):
        if df['catégorie'][i] == 5:
            liste_nom.append(df['lemma'][i])
    
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
    fig.subplots_adjust(wspace=0)

    overall_ratios = proportion
    labels = ['1', '2','3','4','5']

    
    colors=['turquoise','teal','lightgreen','aqua','aquamarine']
    explode = [0.5, 0, 0]
    angle = -180 * overall_ratios[0]
    wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels,wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' },colors=colors)

    age_ratios = liste_prop
    age_labels = liste_nom
    bottom = 1
    width = .2

    for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
        bottom -= height
        bc = ax2.bar(0, height, width, bottom=bottom, color='turquoise', label=label,
                 alpha=0.1 + 0.1 * j)
        ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')
    

    ax2.set_title(5)
    ax2.legend()
    ax2.axis('off')
    ax2.set_xlim(- 3 * width, 3 * width)    

    theta1, theta2 = wedges[0].theta1, wedges[0].theta2
    center, r = wedges[0].center, wedges[0].r
    bar_height = sum(age_ratios)

    x = r * np.cos(np.pi / 180 * theta2) + center[0]
    y = r * np.sin(np.pi / 180 * theta2) + center[1]
    con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)


    x = r * np.cos(np.pi / 180 * theta1) + center[0]
    y = r * np.sin(np.pi / 180 * theta1) + center[1]
    con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
    
    plt.title("Pie chart des lemmes de l'élément 5")

    plt.savefig("Pie_chart_lemmes_5.png")

# %%
pie_chart_1('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/1250-1299 (copie).csv')
# Out:
# /tmp/ipykernel_101628/2713025567.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lol['proportion'] = lol['Occurrences']/lol['Occurrences'].sum()
# /tmp/ipykernel_101628/2713025567.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lol['proportion'] = lol['Occurrences']/lol['Occurrences'].sum()
# /tmp/ipykernel_101628/2713025567.py:160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
files = ["800-849","850-899","900-949","950-999","1000-1049","1050-1099","1100-1149","1150-1199","1200-1249","1250-1299"]

path = "/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/"

liste_fin = []

for file in files:

    path_fin = path + file + " (copie).csv"

    df = pd.read_csv(path_fin)
    df.pop('Unnamed: 0')
    df = df.dropna().reset_index()
    df.pop('index')

    df_vide = pd.DataFrame(columns=['catégorie','Occurrences'])

    x = 0
    y = 0
    z = 0
    a = 0
    b = 0
    for i in range(len(df)):
        if df['catégorie'][i] == 1:
            x += df['Occurrences'][i]
        if df['catégorie'][i] == 2:
            y += df['Occurrences'][i]
        if df['catégorie'][i] == 3:
            z += df['Occurrences'][i]
        if df['catégorie'][i] == 4:
            a += df['Occurrences'][i]
        if df['catégorie'][i] == 5:
            b += df['Occurrences'][i]

    df_vide['catégorie'] = [1,2,3,4,5]
    df_vide['Occurrences'] = [x,y,z,a,b]
    df_vide['proportion'] = df_vide['Occurrences']/df_vide['Occurrences'].sum()

    proportion = df_vide['proportion'].tolist()

    liste_fin.append(proportion)


liste_plot_1 = []
liste_plot_2 = []
liste_plot_3 = []
liste_plot_4 = []
liste_plot_5 = []

for liste in range(len(liste_fin)):
    liste_plot_1.append(liste_fin[liste][0])
    liste_plot_2.append(liste_fin[liste][1])
    liste_plot_3.append(liste_fin[liste][2])
    liste_plot_4.append(liste_fin[liste][3])
    liste_plot_5.append(liste_fin[liste][4])

    
dico = {'Ecclesia' : liste_plot_1, "Socio-juridique" : liste_plot_2, "Possessifs":liste_plot_3, "Administratifs":liste_plot_4, "Autres":liste_plot_5}
df_dico = pd.DataFrame(dico)
df_dico['files'] = files


fig_dims = (12,8)
fig, ax = plt.subplots(figsize = fig_dims)

sns.lineplot(data=df_dico, ax=ax)
tickvalues = df_dico.index
ax.set_xticks(ticks = tickvalues, labels=files)
ax.set_xlabel("Évolution diachronique de la répartition des adjectifs parmi les 5 classes")
ax.set_ylabel("Pourcentage ")
ax.set_title("Évolution de la proportion d'adjectifs à travers le temps", fontsize=20)

plt.savefig("Diagramme_évolutif_cat_adj.png")

# %%
# Out:
#                   1         2         3         4         5
# files
# 800-849    0.380952  0.355742  0.168067  0.000000  0.095238
# 850-899    0.378109  0.390547  0.159204  0.002488  0.069652
# 900-949    0.207317  0.225610  0.347561  0.048780  0.170732
# 950-999    0.523810  0.011905  0.182540  0.007937  0.273810
# 1000-1049  0.276527  0.154341  0.231511  0.038585  0.299035
# 1050-1099  0.208845  0.044226  0.395577  0.031941  0.319410
# 1100-1149  0.351585  0.066282  0.417867  0.005764  0.158501
# 1150-1199  0.425121  0.000000  0.318841  0.000000  0.256039
# 1200-1249  0.188811  0.000000  0.524476  0.006993  0.279720
# 1250-1299  0.189474  0.010526  0.600000  0.052632  0.147368

# %%
noway = hihi.drop_duplicates(subset="canonical_form",keep='last')
