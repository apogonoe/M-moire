# %%
import pandas as pd
import numpy as np
import math
import distance
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
# %matplotlib inline

# %%
def indice_similarite(path1, path2):
    
    
    
    df = pd.read_csv(path1)
    df = df.drop('Unnamed: 0', axis=1)
    df = df[['lemma','Occurrences']]
    df2 = pd.read_csv(path2)
    df2 = df2.drop('Unnamed: 0', axis=1)
    df2 = df2[['lemma','Occurrences']]
    
        
    dic1 = dict(df.values)
    dic1 = {k: v for k, v in dic1.items()}
    dic2 = dict(df2.values)
    dic2 = {k: v for k, v in dic2.items()}
    
    for mot in dic1: 
        if mot not in dic2:
            dic2[mot] = 0
    for mot in dic2:
        if mot not in dic1:
            dic1[mot] = 0
    differences_occurences = 0
    for mot in dic1:
        differences_occurences += abs(dic1[mot] - dic2[mot])
    min_somme = 0
    max_somme = sum(list(dic1.values())) + sum(list(dic2.values()))
    differences_occurences /= max_somme

    
    return (differences_occurences)

# %%
path1 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/
path2 =

# %%
def cosine_sim(path1,path2):
    
    df = pd.read_csv(path1)
    df = df.drop('Unnamed: 0', axis=1)
    df2 = pd.read_csv(path2)
    df2 = df2.drop('Unnamed: 0', axis=1)
    
    
    for i in range(len(df2)):
        df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
    for i in range(len(df)):
        df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()

    num = 0
    for i in range(len(df)):
        for j in range(len(df2)):
            if df['lemma'][i] == df2['lemma'][j]:
                num = num + (df['Occurrences'][i].dot(df2['Occurrences'][j], axis=0)
                
    
    df['carré'] = df['Occurrences']**2
    df2['carré'] = df2['Occurrences']**2
    denom = (math.sqrt(df2['carré'].sum())) * (math.sqrt(df['carré'].sum()))
    final = num/denom
    
    return(final)
# Out:
#   Input In [56]
#     df['carré'] = df['Occurrences']**2
#     ^
# SyntaxError: invalid syntax

# %%
df2['carré'] = df2['Occurrences']**2

# %%
def cosine_sim(path1,path2):
    
    df = pd.read_csv(path1)
    df = df.drop('Unnamed: 0', axis=1)
    df2 = pd.read_csv(path2)
    df2 = df2.drop('Unnamed: 0', axis=1)
    
    for i in range(len(df2)):
        df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
    for i in range(len(df)):
        df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()

    num = 0
    for i in range(len(df)):
        for j in range(len(df2)):
            if df['lemma'][i] == df2['lemma'][j]:
                num = num + (df['Occurrences'][i] * (df2['Occurrences'][j]))
                
    df2['carré'] = df2['Occurrences']**2
    df['carré'] = df['Occurrences'] **2
    denom = (math.sqrt(df2['carré'].sum())) * (math.sqrt(df['carré'].sum()))
    final = num/denom
    
    return(final)

# %%
    grammar = ["QLF","SUB","VBE"]
    
    path = "/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/"
    
    files = ["800-849","850-899","900-949","950-999","1000-1049","1050-1099","1100-1149","1150-1199","1200-1249","1250-1299"]
    
    liste_QLF = []
    liste_VBE = []
    liste_SUB = []
    
    for gram in grammar:
        for file in files:
            if gram == "QLF":
                path_fin = path + gram + "/" + file + ".csv"
                df = pd.read_csv(path_fin)
                df = df.drop('Unnamed: 0', axis=1)
                df = df[['lemma','Occurrences']]
                for lemma in df['lemma']:
                    if lemma not in liste_QLF:
                        liste_QLF.append(lemma)
                        sorted(liste_QLF)
            """if gram == "VBE":
                path_fin = path + gram + "/" + file + ".csv"
                df = pd.read_csv(path_fin)
                df = df.drop('Unnamed: 0', axis=1)
                df = df[['lemma','Occurrences']]
                for lemma in df['lemma']:
                    if lemma not in liste_VBE:
                        liste_VBE.append(lemma)
                        sorted(liste_VBE)
            if gram =="SUB":
                path_fin = path + gram + "/" + file + ".csv"
                df = pd.read_csv(path_fin)
                df = df.drop('Unnamed: 0', axis=1)
                df = df[['lemma','Occurrences']]
                for lemma in df['lemma']:
                    if lemma not in liste_SUB:
                        liste_SUB.append(lemma)
                        """
liste_SUB = sorted(liste_SUB)
liste_VBE = sorted(liste_VBE)
liste_QLF = sorted(liste_QLF)

df
# Out:
#              lemma  Occurrences
# 0             suus           22
# 1           noster           16
# 2             meus           11
# 3             tuus            8
# 4      uenerabilis            8
# 5               --            7
# 6          nobilis            6
# 7        predictus            5
# 8            omnis            5
# 9         inutilis            5
# 10        sanctus1            4
# 11       dilectus1            4
# 12       proprius1            3
# 13         fidelis            3
# 14          quidam            3
# 15          liber2            3
# 16      omnipotens            3
# 17           serus            2
# 18           alius            2
# 19           diues            2
# 20  proprietarius1            2
# 21         deuotus            2
# 22     religiosus1            2
# 23           bonus            2
# 24          dictus            2
# 25       continuus            2
# 26       extraneus            1
# 27         exterus            1
# ...

# %%
        
    for gram in grammar:
        for file in files:
            if gram == "QLF":
                path_fin = path + gram + "/" + file + ".csv"
                
df = pd.read_csv(path_fin)
df = df.drop('Unnamed: 0', axis=1)
df = df[['lemma','Occurrences']]
for i in df['lemma']:
    for j in liste_QLF:
        if i != j:
            df = df.append({'lemma':j, 'Occurrences':0}, ignore_index=True)

# %%
def pearson_sim(path1,path2):
    
    df = pd.read_csv(path1)
    df = df.drop('Unnamed: 0', axis=1)
    df2 = pd.read_csv(path2)
    df2 = df2.drop('Unnamed: 0', axis=1)
    
    for i in range(len(df2)):
        df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
    for i in range(len(df)):
        df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()   
        
    num = 0
    for i in range(len(df)):
        for j in range(len(df2)):
            if df['lemma'][i] == df2['lemma'][j]:
                num = num + ((df['Occurrences'][i] - df['Occurrences'].mean()) * 
                             (df2['Occurrences'][j] - df2['Occurrences'].mean()))
                
    df2['carré'] = (df2['Occurrences'] - df2['Occurrences'].mean()) ** 2
    df['carré'] = (df['Occurrences'] - df['Occurrences'].mean()) **2
    denom = (math.sqrt(df2['carré'].sum())) * (math.sqrt(df['carré'].sum()))
    final = num/denom
    
    return(final)

# %%
def jaccard(path1,path2):
    
    df = pd.read_csv(path1)
    df = df.drop('Unnamed: 0', axis=1)
    df2 = pd.read_csv(path2)
    df2 = df2.drop('Unnamed: 0', axis=1)
    
    for i in range(len(df2)):
        df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
    for i in range(len(df)):
        df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()

    num = 0
    for i in range(len(df)):
        for j in range(len(df2)):
            if df['lemma'][i] == df2['lemma'][j]:
                num = num + (df['Occurrences'][i] * (df2['Occurrences'][j]))
                           
    df2['carré'] = df2['Occurrences']**2
    df['carré'] = df['Occurrences'] **2
    denom = (math.sqrt(df2['carré'].sum())) * (math.sqrt(df['carré'].sum()))
    final = num/(denom - num)
    
    #le dénominateur chiffonne
    
    return(final)

# %%
def Dice_indice(path1,path2):
    
    df = pd.read_csv(path1)
    df = df.drop('Unnamed: 0', axis=1)
    df2 = pd.read_csv(path2)
    df2 = df2.drop('Unnamed: 0', axis=1)
    
    liste = []
    for i in range(len(df)):
        for j in range(len(df2)):
            if df['lemma'][i] == df2['lemma'][j]:
                liste.append(df['lemma'][i])
    
    num = 2 * len(liste)
    denum = len(df) + len(df2)
    
    result = num/denum
    
    return(result)

# %%
files = ["800-849","850-899","900-949","950-999","1000-1049","1050-1099","1100-1149","1150-1199","1200-1249","1250-1299"]

path = "/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/"

grammar = ["QLF","SUB","VBE"]

cos_QLF = []
cos_VBE = []
cos_SUB = []
dice_QLF = []
dice_VBE = []
dice_SUB = []
pear_QLF = []
pear_VBE = []
pear_SUB = []
jac_QLF = []
jac_VBE = []
jac_SUB = []
ind_QLF = []
ind_VBE = []
ind_SUB = []


#for gram in grammar:
for i in range(len(files)-1):

    path1 = path + gram + "/" + files[i] + ".csv"
    path2 = path + gram + "/" + files[i+1] + ".csv"

    #if gram == "QLF":

    cos_QLF.append(cosine_sim(path1,path2))
    dice_QLF.append(Dice_indice(path1,path2))
    pear_QLF.append((pearson_sim(path1,path2))
    print(pear_QLF)
# Out:
#   Input In [106]
#     print(pear_QLF)
#     ^
# SyntaxError: invalid syntax

# %%
files = ["800-849","850-899","900-949","950-999","1000-1049","1050-1099","1100-1149","1150-1199","1200-1249","1250-1299"]

path = "/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/"

cos_QLF = []
dice_QLF = []
pear_QLF = []
jac_QLF = []
ind_QLF = []

for i in range(len(files)-1):

    path1 = path + files[i] + ".csv"
    path2 = path + files[i+1] + ".csv"
    
    cos_QLF.append(cosine_sim(path1,path2))
    dice_QLF.append(Dice_indice(path1,path2))
    pear_QLF.append(pearson_sim(path1,path2))
    jac_QLF.append(jaccard(path1,path2))
    ind_QLF.append(indice_similarite(path1,path2))
# Out:
# /tmp/ipykernel_81450/2829193997.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_81450/2829193997.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# /tmp/ipykernel_81450/1235394149.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
files = ["800-849","850-899","900-949","950-999","1000-1049","1050-1099","1100-1149","1150-1199","1200-1249","1250-1299"]

path = "/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/VBE/"

cos_VBE = []
dice_VBE = []
pear_VBE = []
jac_VBE = []
ind_VBE = []

for i in range(len(files)-1):

    path1 = path + files[i] + ".csv"
    path2 = path + files[i+1] + ".csv"
    
    cos_VBE.append(cosine_sim(path1,path2))
    dice_VBE.append(Dice_indice(path1,path2))
    pear_VBE.append(pearson_sim(path1,path2))
    jac_VBE.append(jaccard(path1,path2))
    ind_VBE.append(indice_similarite(path1,path2))
    
len(jac_VBE)
# Out:
# /tmp/ipykernel_81450/2829193997.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_81450/2829193997.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# /tmp/ipykernel_81450/1235394149.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
files = ["800-849","850-899","900-949","950-999","1000-1049","1050-1099","1100-1149","1150-1199","1200-1249","1250-1299"]

path = "/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/SUB/"

cos_SUB = []
dice_SUB = []
pear_SUB = []
jac_SUB = []
ind_SUB = []

for i in range(len(files)-1):

    path1 = path + files[i] + ".csv"
    path2 = path + files[i+1] + ".csv"
    
    cos_SUB.append(cosine_sim(path1,path2))
    dice_SUB.append(Dice_indice(path1,path2))
    pear_SUB.append(pearson_sim(path1,path2))
    jac_SUB.append(jaccard(path1,path2))
    ind_SUB.append(indice_similarite(path1,path2))
# Out:
# /tmp/ipykernel_81450/2829193997.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_81450/2829193997.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# /tmp/ipykernel_81450/1235394149.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
dico = {'Dice' : dice_SUB, "Pearson" : pear_SUB, "Indice_personnel" : ind_SUB, "Jaccard" : jac_SUB, "Cosinus" : cos_SUB}
df = pd.DataFrame(dico)

# %%
x = indice_similarite('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/SUB/800-849.csv','/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/SUB/850-899.csv')

# %%
x

# %%
fig_dims = (12,8)
fig, ax = plt.subplots(figsize = fig_dims)

sns.lineplot(data=df, ax=ax)
tickvalues = df.index
#ax.set_xticks(ticks = tickvalues, labels=files)
ax.set_xlabel("Demi-siècles")
ax.set_ylabel("Pourcentage ")
ax.set_title("Comparaison des indices de similarité pour seruus (SUB)", fontsize=20)

plt.savefig("indices_comp_(SUB).png", dpi=300)

# %%
colnames = ['indice','pre','word','post']
df = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Word_tags/800-849.csv', header = 4, names=colnames)

# %%
df = df[['pre','word','post']]
# Out:
# 0       Seruorum/SUB
# 1       Seruorum/SUB
# 2       Seruorum/SUB
# 3       Seruorum/SUB
# 4       Seruorum/SUB
#            ...
# 707       seruus/SUB
# 708       seruus/SUB
# 709       seruus/SUB
# 710       seruus/SUB
# 711       seruus/SUB
# Name: word, Length: 712, dtype: object

# %%
df['new'] = df['pre'] + (' ') + df['word']+ (' ') + df['post']
df['new'] = df['new'].str.lower()
df['drop'] = df['new'].str.find('seruus/sub  seruorum/sub  dei/sub ')
df = df[df['drop'] == -1]
df = df.reset_index()
df.pop('index')
df.pop('drop')
df.pop('new')
# Out:
# 0      nostre/nam  munere/nam  locis/nam  deo/sub  di...
# 1      dei/sub  et/con  saluatoris/sub  nostri/qlf  i...
# 2      et/nam  saluatoris/sub  nostri/nam  ihesu/nam ...
# 3      ihesu/nam  christi/nam  hluduuicus/nam  diuina...
# 4      et/nam  saluatoris/sub  nostri/nam  ihesu/nam ...
#                              ...
# 630    guntardo/nam  regembardo/nam  eugento/nam  ada...
# 631    autado/nam  guntardo/nam  regenbaldo/nam  euge...
# 632    iiiia/vbe  regnante/vbe  karolo/nam  gloriosis...
# 633    in/pre  dominationem/sub  supradicti/qlf  mona...
# 634    suprascriptam/qlf  rem/sub  diebus/sub  uite/s...
# Name: new, Length: 635, dtype: object

# %%
liste_1 = df['pre'].str.split(('  ')).tolist()
for i in range(len(liste_1)):
    liste_1[i] = liste_1[i][-5:]
    
liste_2 = df['post'].str.split(('  ')).tolist()
for i in range(len(liste_2)):
    liste_2[i] = liste_2[i][:5]

# %%
liste = []
for i in range(len(liste_1)):
    liste.append(liste_1[i] + liste_2[i])
liste
# Out:
# [['Et/NAM',
#   'Necessitates/NAM',
#   'Ecclesiasticas/NAM',
#   'Ad/NAM',
#   'Petitiones/NAM',
#   ' Dei/SUB',
#   'Nostro/NAM',
#   'Releuamus/NAM',
#   'Iuuamine/SUB',
#   'Atque/NAM'],
#  ['prouidentia/SUB',
#   'Imperator/SUB',
#   'Augustus/NAM </s><s> Si/CON',
#   'Sacerdotum/SUB',
#   'ac/CON',
#   ' Dei/SUB',
#   'petitiones/SUB',
#   'quas/PRO',
#   'nobis/PRO',
#   'pro/PRE'],
#  ['Ordinante/NAM',
#   'Prouidentia/NAM',
#   'Imperator/SUB',
#   'Augustus/NAM </s><s> Cum/PRE',
#   'Petitionibus/NAM',
#   ' Dei/SUB',
#   'Iustis/QLF',
#   'Et/NAM',
#   'Rationabilibus/NAM',
#   'Diuini/QLF'],
#  ['Ob/NAM',
#   'Amorem/NAM',
#   'Dei/SUB',
#   'Pro/NAM',
#   'Oportunitate/NAM',
#   ' Dei/SUB',
#   'agimus/VBE',
#   'hoc/PRO',
#   'nobis/PRO',
#   'ad/PRE'],
#  ['Ordinante/NAM',
#   'Prouidentia/NAM',
#   'Imperator/SUB',
#   'Augustus/NAM </s><s> Cum/PRE',
#   'Petitionibus/NAM',
#   ' Dei/SUB',
#   'Iustis/QLF',
#   'Et/NAM',
#   'Rationabilibus/NAM',
#   'Diuini/QLF'],
# ...

# %%
for i in liste:
    for j in i:
        if j[-3:] != 'QLF':
            i.remove(j)
liste
# Out:
# [[],
#  [],
#  ['Iustis/QLF', 'Diuini/QLF'],
#  [],
#  ['Iustis/QLF', 'Diuini/QLF'],
#  ['Iustis/QLF'],
#  ['Iustis/QLF', 'Iustis/QLF', 'Diuini/QLF'],
#  ['Diuini/QLF'],
#  ['Iustis/QLF', 'Diuini/QLF'],
#  ['Diuinis/QLF'],
#  ['Iustis/QLF', 'Diuini/QLF'],
#  ['Iustis/QLF', 'Diuini/QLF'],
#  ['Iustis/QLF'],
#  [],
#  ['Diuina/QLF'],
#  [],
#  ['Iustis/QLF', 'Diuini/QLF'],
#  ['sanctis/QLF'],
#  ['Iustis/QLF'],
#  ['Suis/QLF'],
#  ['Iustis/QLF', 'Diuini/QLF'],
#  [],
#  [],
#  ['nostre/QLF'],
#  ['Iustis/QLF', 'diuini/QLF'],
#  ['Serenissimi/QLF', 'Sancte/QLF'],
#  ['Iustis/QLF'],
#  ['Iustis/QLF', 'Diuini/QLF'],
#  ['Diuini/QLF'],
#  ['Suis/QLF'],
#  [],
#  [' bone/QLF', 'fidelis/QLF'],
#  [],
#  ['tali/QLF', 'manentes/QLF'],
#  ['sancti/QLF'],
#  [' sancti/QLF'],
#  [],
#  [],
#  ['reliqui/QLF'],
#  ['suas/QLF'],
#  ['nostram/QLF', 'uestris/QLF', 'sancti/QLF'],
#  ['diuerse/QLF', 'liberi/QLF'],
#  ['nostro/QLF', 'tui/QLF', ' indigni/QLF', 'uestro/QLF'],
#  [],
#  ['seruili/QLF'],
# ...

# %%
df['qlf'] = liste  
df['word'] = df['word'].str.split('/').str[0]
df['word'] = df['word'].str.lower()
df['cas_seruus'] = ""
df['cas_qlf']= ""

# %%
for i in range(len(df['qlf'])):
    for j in range(len(df['qlf'][i])):
        df['qlf'][i][j] = df['qlf'][i][j].split('/')[0].lower()

# %%
df['qlf_1'] = ""
df['qlf_2'] = ""
df['qlf_3'] = ""
df['qlf_4'] = ""
df['qlf_5'] = ""

# %%
df.to_excel('cas4.xlsx')

# %%
for i in range(len(liste)):
    for cas in range(len(liste[i])):
        if cas == 0:
            df['qlf_1'][i] = liste[i][cas]
        if cas == 1:
            df['qlf_2'][i] = liste[i][cas]
        if cas == 2:
            df['qlf_3'][i] = liste[i][cas]
        if cas == 3:
            df['qlf_4'][i] = liste[i][cas]
        if cas == 4:
            df['qlf_5'][i] = liste[i][cas]

# %%
for i in range(len(df)):
    if df['word'][i] == ' seruus':
        df['cas_seruus'][i] = 'nom_sg'
    if df['word'][i] == ' seruorum':
        df['cas_seruus'][i] = 'gen_pl'
    if df['word'][i] == ' seruos':
        df['cas_seruus'][i] = 'acc_pl'
    if df['word'][i] == ' seruo':
        df['cas_seruus'][i] = 'dat_sg | abl_sg'
    if df['word'][i] == ' serui':
        df['cas_seruus'][i] = 'gen_sg | nom pl'
    if df['word'][i] == ' seruum':
        df['cas_seruus'][i] = 'acc_sg'
    if df['word'][i] == ' seruis':
        df['cas_seruus'][i] = 'dat_pl | abl_pl'

# %%
df['cas_qlf_1'] = ""
df['cas_qlf_2'] = ""
df['cas_qlf_3'] = ""
df['cas_qlf_4'] = ""
df['cas_qlf_5'] = ""

# %%
for i in range(len(df)):
    if df['qlf_1'][i].endswith(('us','er')):
        df['cas_qlf_1'][i] = ['nom_sg']
    elif df['qlf_1'][i].endswith('is'):
        df['cas_qlf_1'][i] = ['nom_sg','gen_sg','dat_pl','abl_pl']
    elif df['qlf_1'][i].endswith('um'):
        df['cas_qlf_1'][i] = ['acc_sg','gen_pl'] 
    elif df['qlf_1'][i].endswith('e'):
        df['cas_qlf_1'][i] = ['abl_sg'] 
    elif df['qlf_1'][i].endswith('i'):
        df['cas_qlf_1'][i] = ['gen_sg','dat_sg','nom_pl']
    elif df['qlf_1'][i].endswith('is'):
        df['cas_qlf_1'][i] = ['dat_pl','abl_pl','gen_sg ']
    elif df['qlf_1'][i].endswith('os'):
        df['cas_qlf_1'][i] = ['acc_pl']
    elif df['qlf_1'][i].endswith('orum'):
        df['cas_qlf_1'][i] = ['gen_pl']
    elif df['qlf_1'][i].endswith('es'):
        df['cas_qlf_1'][i] = ['nom_pl','acc_pl']
    elif df['qlf_1'][i].endswith('ibus'):
        df['cas_qlf_1'][i] = ['dat_pl','abl_pl']
    elif df['qlf_1'][i].endswith('o'):
        df['cas_qlf_1'][i] = ['dat_sg','abl_sg']
    else:
        df['cas_qlf_1'][i] = [""]

# %%
for i in range(len(df)):
    if df['qlf_2'][i].endswith(('us','er')):
        df['cas_qlf_2'][i] = ['nom_sg']
    elif df['qlf_2'][i].endswith('is'):
        df['cas_qlf_2'][i] = ['nom_sg','gen_sg','dat_pl','abl_pl']
    elif df['qlf_2'][i].endswith('um'):
        df['cas_qlf_2'][i] = ['acc_sg','gen_pl'] 
    elif df['qlf_2'][i].endswith('e'):
        df['cas_qlf_2'][i] = ['abl_sg']
    elif df['qlf_2'][i].endswith('i'):
        df['cas_qlf_2'][i] = ['gen_sg','dat_sg','nom_pl']
    elif df['qlf_2'][i].endswith('is'):
        df['cas_qlf_2'][i] = ['dat_pl','abl_pl','gen_sg ']
    elif df['qlf_2'][i].endswith('os'):
        df['cas_qlf_2'][i] = ['acc_pl']
    elif df['qlf_2'][i].endswith('orum'):
        df['cas_qlf_2'][i] = ['gen_pl'] 
    elif df['qlf_2'][i].endswith('es'):
        df['cas_qlf_2'][i] = ['nom_pl','acc_pl']
    elif df['qlf_2'][i].endswith('ibus'):
        df['cas_qlf_2'][i] = ['dat_pl','abl_pl']
    elif df['qlf_2'][i].endswith('o'):
        df['cas_qlf_2'][i] = ['dat_sg','abl_sg']
    else:
        df['cas_qlf_2'][i] = [""]

# %%
for i in range(len(df)):
    if df['qlf_3'][i].endswith(('us','er')):
        df['cas_qlf_3'][i] = ['nom_sg']
    elif df['qlf_3'][i].endswith('is'):
        df['cas_qlf_3'][i] = ['nom_sg','gen_sg','dat_pl','abl_pl']
    elif df['qlf_3'][i].endswith('um'):
        df['cas_qlf_3'][i] = ['acc_sg','gen_pl'] 
    elif df['qlf_3'][i].endswith('e'):
        df['cas_qlf_3'][i] = ['abl_sg'] 
    elif df['qlf_3'][i].endswith('i'):
        df['cas_qlf_3'][i] = ['gen_sg','dat_sg','nom_pl']
    elif df['qlf_3'][i].endswith('is'):
        df['cas_qlf_3'][i] = ['dat_pl','abl_pl','gen_sg ']
    elif df['qlf_3'][i].endswith('os'):
        df['cas_qlf_3'][i] = ['acc_pl']
    elif df['qlf_3'][i].endswith('orum'):
        df['cas_qlf_3'][i] = ['gen_pl'] 
    elif df['qlf_3'][i].endswith('es'):
        df['cas_qlf_3'][i] = ['nom_pl','acc_pl']
    elif df['qlf_3'][i].endswith('ibus'):
        df['cas_qlf_3'][i] = ['dat_pl','abl_pl']
    elif df['qlf_3'][i].endswith('o'):
        df['cas_qlf_3'][i] = ['dat_sg','abl_sg']
    else:
        df['cas_qlf_3'][i] = [""]

# %%
for i in range(len(df)):
    if df['qlf_4'][i].endswith(('us','er')):
        df['cas_qlf_4'][i] = ['nom_sg']
    elif df['qlf_4'][i].endswith('is'):
        df['cas_qlf_4'][i] = ['nom_sg','gen_sg','dat_pl','abl_pl']
    elif df['qlf_4'][i].endswith('um'):
        df['cas_qlf_4'][i] = ['acc_sg','gen_pl'] 
    elif df['qlf_4'][i].endswith('e'):
        df['cas_qlf_4'][i] = ['abl_sg'] 
    elif df['qlf_4'][i].endswith('i'):
        df['cas_qlf_4'][i] = ['gen_sg','dat_sg','nom_pl']
    elif df['qlf_4'][i].endswith('is'):
        df['cas_qlf_4'][i] = ['dat_pl','abl_pl','gen_sg ']
    elif df['qlf_4'][i].endswith('os'):
        df['cas_qlf_4'][i] = ['acc_pl'] 
    elif df['qlf_4'][i].endswith('orum'):
        df['cas_qlf_4'][i] = ['gen_pl'] 
    elif df['qlf_4'][i].endswith('es'):
        df['cas_qlf_4'][i] = ['nom_pl','acc_pl']
    elif df['qlf_4'][i].endswith('ibus'):
        df['cas_qlf_4'][i] = ['dat_pl','abl_pl']
    elif df['qlf_4'][i].endswith('o'):
        df['cas_qlf_4'][i] = ['dat_sg','abl_sg']
    else:
        df['cas_qlf_4'][i] = [""]

# %%
for i in range(len(df)):
    if df['qlf_5'][i].endswith(('us','er')):
        df['cas_qlf_5'][i] = ['nom_sg']
    elif df['qlf_5'][i].endswith('is'):
        df['cas_qlf_5'][i] = ['nom_sg','gen_sg','dat_pl','abl_pl']
    elif df['qlf_5'][i].endswith('um'):
        df['cas_qlf_5'][i] = ['acc_sg','gen_pl'] 
    elif df['qlf_5'][i].endswith('e'):
        df['cas_qlf_5'][i] = ['abl_sg'] 
    elif df['qlf_5'][i].endswith('i'):
        df['cas_qlf_5'][i] = ['gen_sg','dat_sg','nom_pl']
    elif df['qlf_5'][i].endswith('is'):
        df['cas_qlf_5'][i] = ['dat_pl','abl_pl','gen_sg ']
    elif df['qlf_5'][i].endswith('os'):
        df['cas_qlf_5'][i] = ['acc_pl']
    elif df['qlf_5'][i].endswith('orum'):
        df['cas_qlf_5'][i] = ['gen_pl']
    elif df['qlf_5'][i].endswith('es'):
        df['cas_qlf_5'][i] = ['nom_pl','acc_pl']
    elif df['qlf_5'][i].endswith('ibus'):
        df['cas_qlf_5'][i] = ['dat_pl','abl_pl']
    elif df['qlf_5'][i].endswith('o'):
        df['cas_qlf_5'][i] = ['dat_sg','abl_sg']
    else:
        df['cas_qlf_5'][i] = [""]

# %%
df.to_excel('cas5.xlsx')

# %%
df
# Out:
#                                                    pre       word  \
# 0    Nostre/NAM  Munere/NAM  Locis/NAM  Deo/SUB  Di...   seruorum
# 1    Dei/SUB  et/CON  Saluatoris/SUB  nostri/QLF  I...   seruorum
# 2    Et/NAM  Saluatoris/SUB  Nostri/NAM  Ihesu/NAM ...   seruorum
# 3    Ihesu/NAM  Christi/NAM  Hluduuicus/NAM  Diuina...   seruorum
# 4    Et/NAM  Saluatoris/SUB  Nostri/NAM  Ihesu/NAM ...   seruorum
# ..                                                 ...        ...
# 630  Guntardo/NAM  Regembardo/NAM  Eugento/NAM  Ada...     seruus
# 631  Autado/NAM  Guntardo/NAM  Regenbaldo/NAM  Euge...     seruus
# 632  Iiiia/VBE  regnante/VBE  Karolo/NAM  gloriosis...     seruus
# 633  in/PRE  dominationem/SUB  supradicti/QLF  mona...     seruus
# 634  suprascriptam/QLF  rem/SUB  diebus/SUB  uite/S...     seruus
#
#                                                   post                  qlf  \
# 0     Dei/SUB  Nostro/NAM  Releuamus/NAM  Iuuamine/...                   []
# ...

# %%
liste_res = []
liste_cas = []


for i in range(len(df)):
    for j in range(len(df['cas_qlf_1'][i])):
        if df['cas_qlf_1'][i][j] == df['cas_seruus'][i]:
            liste_res.append(df['qlf_1'][i])
            liste_cas.append(df['cas_qlf_1'][i][j])
for i in range(len(df)):
    for j in range(len(df['cas_qlf_2'][i])):
        if df['cas_qlf_2'][i][j] == df['cas_seruus'][i]:
            liste_res.append(df['qlf_2'][i])
            liste_cas.append(df['cas_qlf_2'][i][j])
for i in range(len(df)):
    for j in range(len(df['cas_qlf_3'][i])):
        if df['cas_qlf_3'][i][j] == df['cas_seruus'][i]:
            liste_res.append(df['qlf_3'][i])
            liste_cas.append(df['cas_qlf_3'][i][j])
for i in range(len(df)):
    for j in range(len(df['cas_qlf_4'][i])):
        if df['cas_qlf_4'][i][j] == df['cas_seruus'][i]:
            liste_res.append(df['qlf_4'][i])
            liste_cas.append(df['cas_qlf_4'][i][j])
for i in range(len(df)):
    for j in range(len(df['cas_qlf_5'][i])):
        if df['cas_qlf_5'][i][j] == df['cas_seruus'][i]:
            liste_res.append(df['qlf_5'][i])
            liste_cas.append(df['cas_qlf_5'][i][j])
liste_res
# Out:
# ['uenerabilium',
#  'diuinum',
#  'pauperum',
#  'pauperum',
#  'ceterorum',
#  'pauperum',
#  'pauperum',
#  'pauperum',
#  'pauperum',
#  'plurimorum',
#  'plurimorum',
#  'prelatorum',
#  ' meorum',
#  'pauperum',
#  'pauperum',
#  'pauperum',
#  'uniuersorum',
#  'uniuersorum',
#  ' suorum',
#  ' suorum',
#  'predictorum',
#  'pauperum',
#  'pauperum',
#  'pauperum',
#  'pauperum',
#  'nostrum',
#  'pauperum',
#  'pauperum',
#  'pauperum',
#  'pauperum',
#  'suos',
#  'colonos',
#  'alteros',
#  ' uniuersos',
#  ' uniuersos',
#  'nominatos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'inienuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
#  'ingenuos',
# ...

# %%
list_tuples_QLF = Counter(liste_res).most_common()
    
dictionnaire_vide = dict(list_tuples_QLF)
    
dict_items = dictionnaire_vide.items()
    
first_hundred = list(dict_items)#[:100]
    
dico_final = dict(first_hundred)
    
b = list(dico_final.keys())
a = list(dico_final.values())

df_final = pd.DataFrame(a,b)
df_final.reset_index(inplace=True)
df_final.columns = ["Words","Occ"]

# %%
df_final
# Out:
#             Words  Occ
# 0        ingenuos  126
# 1        pauperum   17
# 2          noster    9
# 3          suorum    4
# 4        benignum    4
# 5         colonos    3
# 6         nostrum    3
# 7       nostrorum    3
# 8        fidelium    3
# 9                    3
# 10     plurimorum    2
# 11    uniuersorum    2
# 12           suos    2
# 13      uniuersos    2
# 14      predictos    2
# 15           meum    2
# 16           suum    2
# 17        liberum    2
# 18         noster    2
# 19      dominicus    2
# 20          omnes    2
# 21   uenerabilium    1
# 22        diuinum    1
# 23      ceterorum    1
# 24     prelatorum    1
# 25         meorum    1
# 26    predictorum    1
# 27        nostrum    1
# 28        alteros    1
# 29      nominatos    1
# 30       inienuos    1
# 31         quales    1
# 32   consistentes    1
# 33      predictum    1
# 34       proprium    1
# 35       paruulus    1
# 36       proprius    1
# 37       ingenuus    1
# 38      feliciter    1
# ...

# %%
list_tuples_QLF_cas = Counter(liste_cas).most_common()
    
dictionnaire_vide = dict(list_tuples_QLF_cas)
    
dict_items = dictionnaire_vide.items()
    
first_hundred = list(dict_items)#[:100]
    
dico_final = dict(first_hundred)
    
a = list(dico_final.values())
b = list(dico_final.keys())

df_final_cas = pd.DataFrame(a,b)
df_final_cas.reset_index(inplace=True)
df_final_cas.columns = ["Cas","Occ"]

# %%
df_final_cas
# Out:
#       Cas  Occ
# 0  acc_pl  149
# 1  gen_pl   43
# 2  nom_sg   20
# 3  acc_sg   12
# 4            3

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]])
fig.add_trace(go.Pie(labels=df_final_cas["Cas"], values=df_final_cas["Occ"], name="Occurrences par cas"),
              1, 1)
fig.add_trace(go.Pie(labels=df_final['Words'][:10], values=df_final['Occ'][:10], name="Occurrences par mot"),
              1, 2)
fig.update_traces(hole=.4)

fig.update_layout(
    title_text="Adjectifs accordés à seruus entre 800 et 849",
    annotations=[dict(text='Cas', x=0.18, y=0.5, font_size=20, showarrow=False),
                 dict(text='Mots', x=0.82, y=0.5, font_size=20, showarrow=False)])
fig.show()
# Out:
# <div>                            <div id="29c09470-22ee-4f22-8eff-a87a34be2a9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29c09470-22ee-4f22-8eff-a87a34be2a9d")) {                    Plotly.newPlot(                        "29c09470-22ee-4f22-8eff-a87a34be2a9d",                        [{"labels":["acc_pl","gen_pl","nom_sg","acc_sg",""],"name":"Occurrences par cas","values":[149,43,20,12,3],"type":"pie","domain":{"x":[0.0,0.45],"y":[0.0,1.0]},"hole":0.4},{"labels":["ingenuos","pauperum"," noster"," suorum","benignum","colonos"," nostrum","nostrorum","fidelium",""],"name":"Occurrences par mot","values":[126,17,9,4,4,3,3,3,3,3],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]},"hole":0.4}],                        {"template":{"data":{"histogram
# ...

# %%
plt.pie(df_final['Occ'][:10], labels=df_final['Words'][:10])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb8ce457160>,
# ...
#  [Text(-0.7011664649040886, 0.8475645040313473, 'ingenuos'),
#   Text(0.12806562106484273, -1.0925196550640526, 'pauperum'),
#   Text(0.6059868625527535, -0.9180304583255778, ' noster'),
#   Text(0.8018656394496543, -0.7530016575479745, ' suorum'),
#   Text(0.9013818857574278, -0.6304844930911334, 'benignum'),
#   Text(0.9732948791501509, -0.5125398308620446, 'colonos'),
#   Text(1.022754211345542, -0.4049368138055108, ' nostrum'),
#   Text(1.0603592011230474, -0.2926403331629003, 'nostrorum'),
#   Text(1.0856739838140126, -0.17695197334138804, 'fidelium'),
#   Text(1.0984051457136357, -0.05921263268768777, '')])

# %%
#Occurrences des hapax, poids des hapax dans les lexiques de cooccurrences

df.drop('Unnamed: 0', axis=1)
x = 0
for i in range(len(df)):
    if df['Occurrences'][i] == 1:
        x += 1
y = len(df)
x/y
# Out:
# 0.48333333333333334
