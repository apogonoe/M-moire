# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import distance
from collections import Counter
import math
import nltk
# %matplotlib inline

# %%
df = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Lemma_brut/Tags/seruus_complet.csv', sep=',', header=4)

# %%
"""df_final = pd.DataFrame(df['indice'].value_counts())
df_final = df_final.reset_index()
df_final.columns = ['indice', "occurrences"]
df_final['TF-IDF'] = df_final['occurrences']* (math.log10(244085/18127))"""
# Out:
# 'df_final = pd.DataFrame(df[\'indice\'].value_counts())\ndf_final = df_final.reset_index()\ndf_final.columns = [\'indice\', "occurrences"]\ndf_final[\'TF-IDF\'] = df_final[\'occurrences\']* (math.log10(244085/18127))'

# %%
colonnes = ['indice','pre','lemma','post']
df = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/seruus_texte.csv', sep=',', header=4, names=colonnes, encoding ='UTF-8')

# %%
df2 = df['indice'].str.replace(',',' ')

# %%
df2 = df2.str.split()

# %%
df2
# Out:
# 0        [0800_passau_224441, In, nomine, domini, dei, ...
# 1        [0800_pflugk-harttung_236150, Leo, episcopus, ...
# 2        [0800_pflugk-harttung_236150, Leo, episcopus, ...
# 3        [0800_pflugk-harttung_236150, Leo, episcopus, ...
# 4        [0800_saintgall_224984, In, Christi, nomine., ...
#                                ...
# 34229    [9999_marmoutiermanceau_255656, Concordiam, in...
# 34230    [9999_marmoutiervendomois_256306, NOTICIA, DE,...
# 34231    [9999_marmoutiervendomois_256373, NOTICIA, FUL...
# 34232    [9999_montcassin_233318, Anacletus, servus, se...
# 34233    [9999_montcassin_233318, Anacletus, servus, se...
# Name: indice, Length: 34234, dtype: object

# %%
texte = df2.drop_duplicates()

# %%
texte
# Out:
# 0        [0800_passau_224441, In, nomine, domini, dei, ...
# 1        [0800_pflugk-harttung_236150, Leo, episcopus, ...
# 4        [0800_saintgall_224984, In, Christi, nomine., ...
# 6        [0800_stclaude_53057, Sacrosancto, cenobio, Co...
# 7        [0801_mgh-dd-kar-i_216522, (C.), In, nomine, p...
#                                ...
# 34228    [9999_hersfeld_229038, Breve, compendium, de, ...
# 34229    [9999_marmoutiermanceau_255656, Concordiam, in...
# 34230    [9999_marmoutiervendomois_256306, NOTICIA, DE,...
# 34231    [9999_marmoutiervendomois_256373, NOTICIA, FUL...
# 34232    [9999_montcassin_233318, Anacletus, servus, se...
# Name: indice, Length: 18127, dtype: object

# %%
colonnes = ['indice','pre','lemma','post']
dataframe = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Lemma_brut/Tags/seruus_complet.csv', sep=',', header=4, names=colonnes, encoding ='UTF-8')

# %%
indice = dataframe['indice'].drop_duplicates()

# %%
final = dataframe['indice'].value_counts()

# %%
final = final.tolist()

# %%
len(indice)
# Out:
# 18127

# %%
indice = indice.tolist()

# %%
texte_final = []
for i in texte:
    texte_final.append(i[1:])

# %%
len(texte_final[0])
# Out:
# 178

# %%
taille = []
for i in texte_final:
    taille.append(len(i))
    print(len(i))
# Out:
# 178
# 469
# 209
# 123
# 545
# 210
# 448
# 397
# 455
# 477
# 481
# 1346
# 322
# 175
# 157
# 247
# 248
# 163
# 437
# 318
# 307
# 349
# 286
# 98
# 279
# 851
# 764
# 310
# 850
# 505
# 151
# 473
# 445
# 475
# 746
# 680
# 916
# 589
# 629
# 502
# 684
# 505
# 135
# 623
# 375
# 782
# 334
# 335
# 317
# 544
# 196
# 395
# 517
# 230
# 227
# 504
# 780
# 158
# 154
# 309
# 380
# 438
# 81
# 260
# 168
# 119
# 399
# 221
# 780
# 862
# 104
# 466
# 252
# 421
# 536
# 444
# 403
# 586
# 426
# 361
# 1267
# 495
# 325
# 505
# 470
# 519
# 542
# 482
# 783
# 531
# 360
# 270
# 376
# 626
# 394
# 587
# 543
# 401
# 361
# 349
# 462
# 360
# 419
# 431
# 453
# 305
# 504
# 238
# 378
# 427
# 476
# 437
# 466
# 437
# 721
# 548
# 111
# 485
# 669
# 396
# 320
# 475
# 491
# 392
# 236
# 485
# 374
# 332
# 330
# 516
# 468
# 424
# 394
# 772
# 547
# 568
# 213
# 301
# 642
# 431
# 204
# 591
# 777
# 645
# 372
# 454
# 360
# 441
# 189
# 1239
# 205
# 445
# 338
# 191
# 445
# 613
# 752
# 437
# 192
# 177
# 603
# 324
# 485
# 175
# 207
# 606
# ...

# %%
len(taille)
# Out:
# 18127

# %%
df_final = pd.DataFrame(list(zip(indice,final,taille,)))

# %%
df_final.columns = ['indice','occurrence','nbr_tot_mots']
df_final
# Out:
#                                 indice  occurrence  nbr_tot_mots
# 0                   0800_passau_224441          52           178
# 1          0800_pflugk-harttung_236150          42           469
# 2                0800_saintgall_224984          39           209
# 3                  0800_stclaude_53057          37           123
# 4             0801_mgh-dd-kar-i_216522          36           545
# ...                                ...         ...           ...
# 18122             9999_hersfeld_229038           1          1117
# 18123    9999_marmoutiermanceau_255656           1           482
# 18124  9999_marmoutiervendomois_256306           1           229
# 18125  9999_marmoutiervendomois_256373           1           215
# 18126           9999_montcassin_233318           1            30
#
# [18127 rows x 3 columns]

# %%
df_final['TF-IDF'] = (df_final['occurrence']/df_final['nbr_tot_mots'])* (math.log10(244085/18127))

# %%
df_final
# Out:
#                                 indice  occurrence  nbr_tot_mots    TF-IDF
# 0                   0800_passau_224441          52           178  0.329883
# 1          0800_pflugk-harttung_236150          42           469  0.101124
# 2                0800_saintgall_224984          39           209  0.210715
# 3                  0800_stclaude_53057          37           123  0.339683
# 4             0801_mgh-dd-kar-i_216522          36           545  0.074590
# ...                                ...         ...           ...       ...
# 18122             9999_hersfeld_229038           1          1117  0.001011
# 18123    9999_marmoutiermanceau_255656           1           482  0.002343
# 18124  9999_marmoutiervendomois_256306           1           229  0.004931
# 18125  9999_marmoutiervendomois_256373           1           215  0.005252
# 18126           9999_montcassin_233318           1            30  0.037641
#
# [18127 rows x 4 columns]

# %%
colonnes = ['indice','pre','lemma','post']
df = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Lemma_brut/Without_tags/seruus_lemme.csv', sep=',', header=4, names=colonnes, encoding ='UTF-8')

# %%
df
# Out:
#                                indice  occurrence
# 0        0892_brescia-s-giulia_126486          20
# 1                     0951_cluny_2214          10
# 2                 0971_beaulieu_70564          10
# 3                0880_novalaise_69285          10
# 4                    0951_cluny_50158          10
# ...                               ...         ...
# 5279                  1005_cluny_4029           1
# 5280               1005_gellone_62221           1
# 5281          1005_mgh-dd-h-ii_220134           1
# 5282        1005_tours-stjulien_53915           1
# 5283  9999_marmoutiervendomois_256373           1
#
# [5284 rows x 2 columns]

# %%
colonnes = ['indice','pre','lemma','post']
df = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Lemma_brut/Without_tags/seruus_lemme.csv', sep=',', header=4, names=colonnes, encoding ='UTF-8')
df['new'] = df['pre'] + (' ') + df['lemma']+ (' ') + df['post']
df['new'] = df['new'].str.lower()
df['drop'] = df['new'].str.find('seruus2 seruus2 deus')
df = df[df['drop'] == -1]
df = df.drop("drop", axis=1)
df = df['indice'].value_counts()
df = df.reset_index()
df.columns = ['indice','occurrence']

final = pd.merge(df_final,df, on = 'indice')
final = final.drop('occurrence_x', axis=1)

final.columns = ['indice','nbr_tot_mots','TF-IDF','Occurrences']
final['TF-IDF'] = (final['Occurrences']/final['nbr_tot_mots'])* (math.log10(244085/len(indice)))
final['Fréquence'] = (final['Occurrences']/final['nbr_tot_mots'])
final = final.describe()
final
# Out:
#        nbr_tot_mots       TF-IDF  Occurrences    Fréquence
# count   5284.000000  5284.000000  5284.000000  5284.000000
# mean     483.261734     0.005216     1.366957     0.004619
# std      414.543880     0.005901     0.891998     0.005226
# min        9.000000     0.000376     1.000000     0.000333
# 25%      237.000000     0.002244     1.000000     0.001988
# 50%      380.000000     0.003573     1.000000     0.003165
# 75%      572.000000     0.005943     1.000000     0.005263
# max     3009.000000     0.125468    20.000000     0.111111

# %%
plt.figure(figsize=(15,15))
#plt.ylim(0,0.2)
frame1 = plt.gca()
frame1.axes.xaxis.set_ticklabels([])
plt.scatter(final['indice'],final['TF-IDF'])

# %%
df = df['indice'].value_counts()

# %%
df = df.reset_index()

# %%
df.columns = ['indice','occurrence']

# %%
df
# Out:
#                                indice  occurrence
# 0        0892_brescia-s-giulia_126486           1
# 1              0931_mgh-dd-h-i_218780           1
# 2        0927_robert-ier-raoul_279174           1
# 3        0927_robert-ier-raoul_279175           1
# 4        0927_robert-ier-raoul_279176           1
# ...                               ...         ...
# 5279                  1084_cluny_5018           1
# 5280        1084_le-bechellouin_29328           1
# 5281        1110_dijon-stbenigne_8633           1
# 5282                   1108_wub_60073           1
# 5283  9999_marmoutiervendomois_256373           1
#
# [5284 rows x 2 columns]

# %%
df_final
# Out:
#                                 indice  occurrence  nbr_tot_mots
# 0                   0800_passau_224441          52           178
# 1          0800_pflugk-harttung_236150          42           469
# 2                0800_saintgall_224984          39           209
# 3                  0800_stclaude_53057          37           123
# 4             0801_mgh-dd-kar-i_216522          36           545
# ...                                ...         ...           ...
# 18122             9999_hersfeld_229038           1          1117
# 18123    9999_marmoutiermanceau_255656           1           482
# 18124  9999_marmoutiervendomois_256306           1           229
# 18125  9999_marmoutiervendomois_256373           1           215
# 18126           9999_montcassin_233318           1            30
#
# [18127 rows x 3 columns]

# %%
final = pd.merge(df_final,df, on = 'indice')

# %%
final
# Out:
#                                indice  occurrence_x  nbr_tot_mots  \
# 0                  0800_passau_224441            52           178
# 1         0800_pflugk-harttung_236150            42           469
# 2               0800_saintgall_224984            39           209
# 3                 0800_stclaude_53057            37           123
# 4            0801_mgh-dd-kar-i_216522            36           545
# ...                               ...           ...           ...
# 5279                   1299_wub_59832             1           225
# 5280             9999_hersfeld_229038             1          1117
# 5281    9999_marmoutiermanceau_255656             1           482
# 5282  9999_marmoutiervendomois_256306             1           229
# 5283  9999_marmoutiervendomois_256373             1           215
#
#       occurrence_y
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 5279             1
# ...

# %%
# Out:
#                         indice  nbr_tot_mots  occurrence_y
# 0           0800_passau_224441           178             1
# 1  0800_pflugk-harttung_236150           469             1
# 2        0800_saintgall_224984           209             1
# 3          0800_stclaude_53057           123             1
# 4     0801_mgh-dd-kar-i_216522           545             1

# %%
final = final.drop('occurrence_x', axis=1)
final.columns = ['indice','nbr_tot_mots','TF-IDF','Occurrences']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <module>
#       1 final = final.drop('occurrence_x', axis=1)
# ----> 2 final.columns = ['indice','nbr_tot_mots','TF-IDF','Occurrences']
#
# File ~/python/miniconda/lib/python3.9/site-packages/pandas/core/generic.py:5596, in NDFrame.__setattr__(self, name, value)
#    5594 try:
#    5595     object.__getattribute__(self, name)
# -> 5596     return object.__setattr__(self, name, value)
#    5597 except AttributeError:
#    5598     pass
#
# File ~/python/miniconda/lib/python3.9/site-packages/pandas/_libs/properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/python/miniconda/lib/python3.9/site-packages/pandas/core/generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# ...

# %%
final['TF-IDF'] = (final['Occurrences']/df_final['nbr_tot_mots'])* (math.log10(244085/len(df['indice'])))

# %%
final['Fréquence'] = final['Occurrences']/final['nbr_tot_mots']

# %%
final
# Out:
#                                indice  nbr_tot_mots  Occurrences    TF-IDF  \
# 0                  0800_passau_224441           178            1  0.006344
# 1         0800_pflugk-harttung_236150           469            1  0.002408
# 2               0800_saintgall_224984           209            2  0.010806
# 3                 0800_stclaude_53057           123            1  0.009181
# 4            0801_mgh-dd-kar-i_216522           545            1  0.002072
# ...                               ...           ...          ...       ...
# 5279                   1299_wub_59832           225            1  0.005019
# 5280             9999_hersfeld_229038          1117            1  0.001011
# 5281    9999_marmoutiermanceau_255656           482            1  0.002343
# 5282  9999_marmoutiervendomois_256306           229            1  0.004931
# 5283  9999_marmoutiervendomois_256373           215            1  0.005252
#
#       Fréquence
# 0      0.005618
# 1      0.002132
# ...

# %%
#plt.ylim(0,0.2)
frame1 = plt.gca()
frame1.axes.xaxis.set_ticklabels([])
plt.scatter(final['indice'],final['TF-IDF'])

# %%
fig, ax = plt.subplots(2, figsize=(10, 6))

ax[0].scatter(x = final['indice'], y = final['Fréquence'])
ax[0].set_xlabel("Chartes")
ax[0].set_ylabel("Fréquence")

ax[1].scatter(x = final['indice'], y = final['Tf-IDF'])
ax[1].set_xlabel("Chartes")
ax[1].set_ylabel("TF-IDF")

# %%
def csv_scatter_TF_IDF(path,path2):
    
    #le deuxième path sert à alléger la commande et ne pas itérer dans le gros dataframe
    
    colonnes = ['indice','pre','lemma','post']
    df = pd.read_csv(path, sep=',', header=4, names=colonnes, encoding ='UTF-8')
    
    df2 = df['indice'].str.replace(',',' ')
    df2 = df2.str.split()
    texte = df2.drop_duplicates()
    
    texte_final = []
    for i in texte:
        texte_final.append(i[1:])
    taille = []
    for i in texte_final:
        taille.append(len(i))
            
    dataframe = pd.read_csv(path2, sep=',', header=4, names=colonnes, encoding ='UTF-8')
    final = dataframe['indice'].value_counts()
    final = final.tolist()
    indice = dataframe['indice'].drop_duplicates()
    indice = indice.tolist()
    
    
    df_final = pd.DataFrame(list(zip(indice,final,taille,)))
    df_final.columns = ['indice','occurrence','nbr_tot_mots']
    
    df_final['TF-IDF'] = (df_final['occurrence']/df_final['nbr_tot_mots'])* (math.log10(244085/len(indice)))
    df_final['Fréquence'] = (df_final['occurrence']/df_final['nbr_tot_mots'])
    
    return df_final.describe()

# %%
path1 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Mancipium/Word/mancipium_texte.csv')
path2 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Mancipium/Lemma/mancipium_complet.csv')
path3 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Ancilla/Lemma/ancilla_texte.csv')
path4 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Ancilla/Lemma/ancilla_complet.csv')
path5 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Colonus/Colonus_texte.csv')
path6 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Colonus/Colonus_complet.csv')
path7 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Famulus/Lemma/Famulus_texte.csv')
path8 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Famulus/Lemma/famulus_complet.csv')
path9 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Sclauus/Sclauus_texte.csv')
path10 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Sclauus/Sclauus_complet.csv')
path11 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Serua/Lemma/Serua_texte.csv')
path12 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Serua/Lemma/serua_complet.csv')
path13 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/seruus_texte.csv')
path14 = ('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Lemma_brut/Without_tags/seruus_lemme.csv')

# %%
final_occurrences = final['Occurrences'].tolist()
final_frequence = final["Fréquence"].tolist()
final_nbr = final['nbr_tot_mots'].tolist()
final_idf = final['TF-IDF'].tolist()

# %%
a = csv_scatter_TF_IDF(path1,path2)
b = csv_scatter_TF_IDF(path3,path4)
c = csv_scatter_TF_IDF(path5,path6)
d = csv_scatter_TF_IDF(path7,path8)
e = csv_scatter_TF_IDF(path9,path10)
f = csv_scatter_TF_IDF(path11,path12)
g = csv_scatter_TF_IDF(path13,path14)

# %%
occurrences_final = pd.DataFrame(list(zip(final_occurrences, a_occurrences,b_occurrences,c_occurrences,d_occurrences,e_occurrences,f_occurrences,g_occurrences)))
occurrences_final.columns = ['seruus','mancipium','ancilla','colonus','famulus','sclauus','serua','seruus_brut']
occurrences_final.index = ['nombre de textes','moyenne','écart type','minimum','25%','médiane','75%','maximum']
occurrences_final
# Out:
#                        seruus    mancipium      ancilla     colonus  \
# nombre de textes  5284.000000  3342.000000  2023.000000  248.000000
# moyenne              1.366957     1.402454     1.409293    1.201613
# écart type           0.891998     1.017903     1.285833    0.561661
# minimum              1.000000     1.000000     1.000000    1.000000
# 25%                  1.000000     1.000000     1.000000    1.000000
# médiane              1.000000     1.000000     1.000000    1.000000
# 75%                  1.000000     1.000000     1.000000    1.000000
# maximum             20.000000    17.000000    28.000000    5.000000
#
#                       famulus     sclauus        serua   seruus_brut
# nombre de textes  2176.000000  214.000000  2034.000000  18127.000000
# moyenne              1.314798    1.317757     1.291544      1.888564
# écart type           1.187940    1.075534     1.195193      0.954640
# minimum              1.000000    1.000000     1.000000      1.000000
# ...

# %%
a_occurrences = a['occurrence'].tolist()
b_occurrences = b['occurrence'].tolist()
c_occurrences = c['occurrence'].tolist()
d_occurrences = d['occurrence'].tolist()
e_occurrences = e['occurrence'].tolist()
f_occurrences = f['occurrence'].tolist()
g_occurrences = g['occurrence'].tolist()

# %%
a_idf = a['TF-IDF'].tolist()
b_idf = b['TF-IDF'].tolist()
c_idf = c['TF-IDF'].tolist()
d_idf = d['TF-IDF'].tolist()
e_idf = e['TF-IDF'].tolist()
f_idf = f['TF-IDF'].tolist()
g_idf = g['TF-IDF'].tolist()

# %%
idf_final = pd.DataFrame(list(zip(final_idf, a_idf,b_idf,c_idf,d_idf,e_idf,f_idf,g_idf)))
idf_final.columns = ['seruus','mancipium','ancilla','colonus','famulus','sclauus','serua','seruus_brut']
idf_final.index = ['nombre de textes','moyenne','écart type','minimum','25%','médiane','75%','maximum']
idf_final
# Out:
#                        seruus    mancipium      ancilla     colonus  \
# nombre de textes  5284.000000  3342.000000  2023.000000  248.000000
# moyenne              0.005216     0.009490     0.010083    0.010241
# écart type           0.005901     0.011356     0.015278    0.007909
# minimum              0.000376     0.000621     0.000693    0.000997
# 25%                  0.002244     0.004969     0.003552    0.005224
# médiane              0.003573     0.007090     0.006158    0.008223
# 75%                  0.005943     0.010073     0.011236    0.012350
# maximum              0.125468     0.257039     0.225904    0.061083
#
#                       famulus     sclauus        serua   seruus_brut
# nombre de textes  2176.000000  214.000000  2034.000000  18127.000000
# moyenne              0.010561    0.013007     0.008363      0.009763
# écart type           0.010547    0.017344     0.014212      0.009348
# minimum              0.000670    0.001019     0.000686      0.000376
# ...

# %%
a_frequence = a['Fréquence'].tolist()
b_frequence = b['Fréquence'].tolist()
c_frequence = c['Fréquence'].tolist()
d_frequence = d['Fréquence'].tolist()
e_frequence = e['Fréquence'].tolist()
f_frequence = f['Fréquence'].tolist()
g_frequence = g['Fréquence'].tolist()

# %%
a_nbr = a['nbr_tot_mots'].tolist()
b_nbr = b['nbr_tot_mots'].tolist()
c_nbr = c['nbr_tot_mots'].tolist()
d_nbr = d['nbr_tot_mots'].tolist()
e_nbr = e['nbr_tot_mots'].tolist()
f_nbr = f['nbr_tot_mots'].tolist()
g_nbr = g['nbr_tot_mots'].tolist()

# %%
frequence_final = pd.DataFrame(list(zip(final_frequence, a_frequence,b_frequence,c_frequence,d_frequence,e_frequence,f_frequence,g_frequence)))
frequence_final.columns = ['seruus','mancipium','ancilla','colonus','famulus','sclauus','serua','seruus_brut']
frequence_final.index = ['nombre de textes','moyenne','écart type','minimum','25%','médiane','75%','maximum']
frequence_final
# Out:
#                        seruus    mancipium      ancilla     colonus  \
# nombre de textes  5284.000000  3342.000000  2023.000000  248.000000
# moyenne              0.004619     0.005092     0.004844    0.003422
# écart type           0.005226     0.006094     0.007340    0.002642
# minimum              0.000333     0.000333     0.000333    0.000333
# 25%                  0.001988     0.002667     0.001706    0.001745
# médiane              0.003165     0.003805     0.002959    0.002747
# 75%                  0.005263     0.005405     0.005398    0.004126
# maximum              0.111111     0.137931     0.108527    0.020408
#
#                       famulus     sclauus        serua   seruus_brut
# nombre de textes  2176.000000  214.000000  2034.000000  18127.000000
# moyenne              0.005152    0.004255     0.004022      0.008646
# écart type           0.005145    0.005673     0.006835      0.008278
# minimum              0.000327    0.000333     0.000330      0.000333
# ...

# %%
nbr_final = pd.DataFrame(list(zip(final_nbr, a_nbr,b_nbr,c_nbr,d_nbr,e_nbr,f_nbr,g_nbr)))
nbr_final.columns = ['seruus','mancipium','ancilla','colonus','famulus','sclauus','serua','seruus_brut']
nbr_final.index = ['nombre de textes','moyenne','écart type','minimum','25%','médiane','75%','maximum']
nbr_final
# Out:
#                        seruus    mancipium      ancilla      colonus  \
# nombre de textes  5284.000000  3342.000000  2023.000000   248.000000
# moyenne            483.261734   384.800120   531.556599   545.971774
# écart type         414.543880   299.163969   474.326740   487.132595
# minimum              9.000000    23.000000    25.000000    99.000000
# 25%                237.000000   232.000000   246.000000   267.500000
# médiane            380.000000   301.000000   391.000000   411.000000
# 75%                572.000000   427.000000   642.500000   627.250000
# maximum           3009.000000  3001.000000  3002.000000  3001.000000
#
#                       famulus      sclauus        serua   seruus_brut
# nombre de textes  2176.000000   214.000000  2034.000000  18127.000000
# moyenne            446.493107   544.546729   537.861849    381.530479
# écart type         438.684820   446.282206   457.506177    362.591337
# ...

# %%
plt.figure(figsize=(15,15))
plt.ylim(0,0.2)
frame1 = plt.gca()
frame1.axes.xaxis.set_ticklabels([])
plt.scatter(x['indice'],x['TF-IDF'])
