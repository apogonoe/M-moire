# %%
import pandas as pd
import numpy as np
import math
import distance
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def cosine_sim(path1,path2):
    
    df = pd.read_csv(path1)
    df = df.drop('Unnamed: 0', axis=1)
    df2 = pd.read_csv(path2)
    df2 = df2.drop('Unnamed: 0', axis=1)
    
    for i in range(len(df2)):
        df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
    for i in range(len(df)):
        df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()

    num = 0
    for i in range(len(df)):
        for j in range(len(df2)):
            if df['lemma'][i] == df2['lemma'][j]:
                num = num + (df['Occurrences'][i]*df2['Occurrences'][j])
                
    df2['carré'] = df2['Occurrences']**2
    df['carré'] = df['Occurrences'] **2
    denom = (math.sqrt(df2['carré'].sum())) * (math.sqrt(df['carré'].sum()))
    final = num/denom
    
    return(final)

# %%
cosine_sim('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Mancipium/Cooccurrences/QLF/cooccurrences_QLF',
          '/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Ancilla/Cooccurrences/QLF/cooccurrences_QLF')
# Out:
# /tmp/ipykernel_62635/745551899.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_62635/745551899.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# 0.38510779561064484

# %%
df = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/cooccurrences_QLF')

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df2 = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Ancilla/Cooccurrences/QLF/cooccurrences_QLF')

# %%
df2 = df2.drop('Unnamed: 0', axis=1)

# %%
def Dice_indice(path1,path2):
    
    df = pd.read_csv(path1)
    df = df.drop('Unnamed: 0', axis=1)
    df2 = pd.read_csv(path2)
    df2 = df2.drop('Unnamed: 0', axis=1)
    
    liste = []
    for i in range(len(df)):
        for j in range(len(df2)):
            if df['lemma'][i] == df2['lemma'][j]:
                liste.append(df['lemma'][i])
    
    num = 2 * len(liste)
    denum = len(df) + len(df2)
    
    result = num/denum
    
    return(result)

# %%
Dice_indice('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/cooccurrences_QLF',
          '/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/QLF/cooccurrences_QLF')
# Out:
# 1.0

# %%
def pearson_sim(path1,path2):
    
    df = pd.read_csv(path1)
    df = df.drop('Unnamed: 0', axis=1)
    df2 = pd.read_csv(path2)
    df2 = df2.drop('Unnamed: 0', axis=1)
    
    for i in range(len(df2)):
        df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
    for i in range(len(df)):
        df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()   
        
    num = 0
    for i in range(len(df)):
        for j in range(len(df2)):
            if df['lemma'][i] == df2['lemma'][j]:
                num = num + ((df['Occurrences'][i] - df['Occurrences'].mean()) * 
                             (df2['Occurrences'][j] - df2['Occurrences'].mean()))
                
    df2['carré'] = (df2['Occurrences'] - df2['Occurrences'].mean()) ** 2
    df['carré'] = (df['Occurrences'] - df['Occurrences'].mean()) **2
    denom = (math.sqrt(df2['carré'].sum())) * (math.sqrt(df['carré'].sum()))
    final = num/denom
    
    return(final)

# %%
indice_similarite('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Mancipium/Cooccurrences/SUB/800-849.csv',
          '/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/SUB/800-849.csv')
# Out:
# 0.13867488443759635

# %%
Dice_indice('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/SUB/1100-1149.csv',
          '/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/SUB/950-999.csv')
# Out:
# 0.44

# %%
cosine_sim('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/SUB/800-849.csv',
          '/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Ancilla/Cooccurrences/SUB/800-849.csv')
# Out:
# /tmp/ipykernel_62635/745551899.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_62635/745551899.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# 0.2305234508574119

# %%
jaccard('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/SUB/800-849.csv',
          '/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Ancilla/Cooccurrences/SUB/800-849.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <module>
# ----> 1 jaccard('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/SUB/800-849.csv',
#       2           '/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Ancilla/Cooccurrences/SUB/800-849.csv')
#
# NameError: name 'jaccard' is not defined

# %%
pearson_sim('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurrences/SUB/800-849.csv',
          '/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Ancilla/Cooccurrences/SUB/800-849.csv')
# Out:
# /tmp/ipykernel_62635/1235394149.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_62635/1235394149.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# 0.1854542593204221

# %%
def jaccard(path1,path2):
    
    df = pd.read_csv(path1)
    df = df.drop('Unnamed: 0', axis=1)
    df2 = pd.read_csv(path2)
    df2 = df2.drop('Unnamed: 0', axis=1)
    
    for i in range(len(df2)):
        df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
    for i in range(len(df)):
        df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()

    num = 0
    for i in range(len(df)):
        for j in range(len(df2)):
            if df['lemma'][i] == df2['lemma'][j]:
                num = num + (df['Occurrences'][i]*df2['Occurrences'][j])
                
    df2['carré'] = df2['Occurrences']**2
    df['carré'] = df['Occurrences'] **2
    denom = (math.sqrt(df2['carré'].sum())) * (math.sqrt(df['carré'].sum()))
    final = num/(denom - num)
    
    return(final)

# %%
def euclidean(path1,path2):
    
    df = pd.read_csv(path1)
    df = df.drop('Unnamed: 0', axis=1)
    df2 = pd.read_csv(path2)
    df2 = df2.drop('Unnamed: 0', axis=1)
    
    for i in range(len(df)):
        df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
    for i in range(len(df2)):
        df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()

    eucl = 0
    for i in range(len(final_df)):
        for j in range(len(final_df2)):
            if df2['lemma'][j] not in 
            
            if df['lemma'][i] == df2['lemma'][j]:
                value = (df['Occurrences'][i] - df2['Occurrences'][j])
                eucl = eucl + (value**2)
                
    final = math.sqrt(eucl)
    return(1 - final)
# Out:
#   Input In [18]
#     if df2['lemma'][j] not in
#                               ^
# SyntaxError: invalid syntax

# %%
def indice_similarite(path1, path2):
    
    df = pd.read_csv(path1)
    df = df.drop('Unnamed: 0', axis=1)
    df = df[['lemma','Occurrences']]
    df2 = pd.read_csv(path2)
    df2 = df2.drop('Unnamed: 0', axis=1)
    df2 = df2[['lemma','Occurrences']]
    
        
    dic1 = dict(df.values)
    dic1 = {k: v for k, v in dic1.items()}
    dic2 = dict(df2.values)
    dic2 = {k: v for k, v in dic2.items()}
    
    for mot in dic1: 
        if mot not in dic2:
            dic2[mot] = 0
    for mot in dic2:
        if mot not in dic1:
            dic1[mot] = 0
    differences_occurences = 0
    for mot in dic1:
        differences_occurences += abs(dic1[mot] - dic2[mot])
    min_somme = 0
    max_somme = sum(list(dic1.values())) + sum(list(dic2.values()))
    differences_occurences /= max_somme

    
    return 1 - differences_occurences

# %%
def somme_indices(lemme1,lemme2):
    
    files = ["800-849","850-899","900-949","950-999","1000-1049","1050-1099","1100-1149","1150-1199","1200-1249","1250-1299"]

    path = f"/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/{lemme1}"

    
    path_2 = f"/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/{lemme2}"
    
    grammar = ["QLF","SUB","VBE"]
    
    liste = []
    
    for gram in grammar:
        for file in files:
            path_ij = path + "/Cooccurrences/" + gram + "/" + file + ".csv"
            path_lemme = path_2 + "/Cooccurrences/" + gram + "/" + file + ".csv"
            liste.append(indice_similarite(path_lemme,path_ij))
            liste.append(Dice_indice(path_lemme,path_ij))
            liste.append(pearson_sim(path_lemme,path_ij))
            liste.append(jaccard(path_lemme,path_ij))
            liste.append(cosine_sim(path_lemme,path_ij))             

    
    return sum(liste)

# %%
somme_indices('Mancipium','Famulus')
# Out:
# /tmp/ipykernel_62635/1235394149.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_62635/1235394149.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# /tmp/ipykernel_62635/3244870969.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
def somme_indices_QLF(lemme):
    
    files = ["800-849","850-899","900-949","950-999","1000-1049","1050-1099","1100-1149","1150-1199","1200-1249","1250-1299"]

    path = f"/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/{lemme}"

    
    path_2 = "/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus"
    
    
    liste = []
    
    for file in files:
        path_ij = path + "/Cooccurrences/" + "QLF" + "/" + file + ".csv"
        path_seruus = path_2 + "/Cooccurrences/" + "QLF" + "/" + file + ".csv"
        liste.append(indice_similarite(path_seruus,path_ij))
        liste.append(Dice_indice(path_seruus,path_ij))
        liste.append(pearson_sim(path_seruus,path_ij))
        liste.append(jaccard(path_seruus,path_ij))
        liste.append(cosine_sim(path_seruus,path_ij))             

    
    return sum(liste)

# %%
def somme_indices_VBE(lemme):
    
    files = ["800-849","850-899","900-949","950-999","1000-1049","1050-1099","1100-1149","1150-1199","1200-1249","1250-1299"]

    path = f"/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/{lemme}"

    
    path_2 = "/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus"
    
    
    liste = []
    
    for file in files:
        path_ij = path + "/Cooccurrences/" + "VBE" + "/" + file + ".csv"
        path_seruus = path_2 + "/Cooccurrences/" + "VBE" + "/" + file + ".csv"
        liste.append(indice_similarite(path_seruus,path_ij))
        liste.append(Dice_indice(path_seruus,path_ij))
        liste.append(pearson_sim(path_seruus,path_ij))
        liste.append(jaccard(path_seruus,path_ij))
        liste.append(cosine_sim(path_seruus,path_ij))             

    
    return sum(liste)

# %%
def somme_indices_SUB(lemme):
    
    files = ["800-849","850-899","900-949","950-999","1000-1049","1050-1099","1100-1149","1150-1199","1200-1249","1250-1299"]

    path = f"/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/{lemme}"

    
    path_2 = "/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus"
    
    
    liste = []
    
    for file in files:
        path_ij = path + "/Cooccurrences/" + "SUB" + "/" + file + ".csv"
        path_seruus = path_2 + "/Cooccurrences/" + "SUB" + "/" + file + ".csv"
        liste.append(indice_similarite(path_seruus,path_ij))
        liste.append(Dice_indice(path_seruus,path_ij))
        liste.append(pearson_sim(path_seruus,path_ij))
        liste.append(jaccard(path_seruus,path_ij))
        liste.append(cosine_sim(path_seruus,path_ij))             

    
    return sum(liste)

# %%
somme_indices_QLF("Ancilla")
# Out:
# /tmp/ipykernel_62635/1235394149.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_62635/1235394149.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# /tmp/ipykernel_62635/3244870969.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
somme_indices_QLF('Mancipium')
# Out:
# /tmp/ipykernel_68003/1235394149.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_68003/1235394149.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# /tmp/ipykernel_68003/3244870969.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
somme_indices_QLF('Serua')
# Out:
# /tmp/ipykernel_68003/1235394149.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_68003/1235394149.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# /tmp/ipykernel_68003/3244870969.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
somme_indices_QLF('Famulus')
# Out:
# /tmp/ipykernel_68003/1235394149.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_68003/1235394149.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# /tmp/ipykernel_68003/3244870969.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
somme_indices_QLF('Molina')
# Out:
# /tmp/ipykernel_68003/1235394149.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_68003/1235394149.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# /tmp/ipykernel_68003/3244870969.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
lemmes = ['Ancilla','Mancipium','Famulus','Serua','Molina']
indices = [39.38760109301379,32.602106641698654,36.19213281947696,39.556390672636006,26.128376278023197]

c = '#3cb32d'

plt.figure(figsize=(15,10), dpi=300)
plt.title("Comparaison de la somme des indices de similarité", fontsize=20)
plt.bar(lemmes,indices, edgecolor='black',color=c)
plt.savefig('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Indices/Comparaison de la somme des indices de similarité.png', dpi= 300)

# %%
lemmes = ['Ancilla','Mancipium','Famulus','Serua','Molina']
indices = [somme_indices_QLF("Ancilla"),somme_indices_QLF("Mancipium"),somme_indices_QLF("Famulus")
           ,somme_indices_QLF("Serua"),somme_indices_QLF("Molina")]

c = '#3cb32d'

plt.figure(figsize=(15,10), dpi=300)
plt.title("Comparaison de la somme des indices de similarité (QLF)", fontsize=20)
plt.bar(lemmes,indices, edgecolor='black',color=c)
plt.savefig('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Indices/Comparaison de la somme des indices de similarité (QLF).png', dpi= 300)
# Out:
# /tmp/ipykernel_68003/1235394149.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_68003/1235394149.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# /tmp/ipykernel_68003/3244870969.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
lemmes = ['Ancilla','Mancipium','Famulus','Serua','Molina']
indices = [somme_indices_VBE("Ancilla"),somme_indices_VBE("Mancipium"),somme_indices_VBE("Famulus")
           ,somme_indices_VBE("Serua"),somme_indices_VBE("Molina")]

c = '#3cb32d'

plt.figure(figsize=(15,10), dpi=300)
plt.title("Comparaison de la somme des indices de similarité (VBE)", fontsize=20)
plt.bar(lemmes,indices, edgecolor='black',color=c)
plt.savefig('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Indices/Comparaison de la somme des indices de similarité (VBE).png', dpi= 300)
# Out:
# /tmp/ipykernel_68003/1235394149.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_68003/1235394149.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# /tmp/ipykernel_68003/3244870969.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
lemmes = ['Ancilla','Mancipium','Famulus','Serua','Molina']
indices = [somme_indices_SUB("Ancilla"),somme_indices_SUB("Mancipium"),somme_indices_SUB("Famulus")
           ,somme_indices_SUB("Serua"),somme_indices_SUB("Molina")]

c = '#3cb32d'

plt.figure(figsize=(15,10), dpi=300)
plt.title("Comparaison de la somme des indices de similarité (SUB)", fontsize=20)
plt.bar(lemmes,indices, edgecolor='black',color=c)
plt.savefig('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Indices/Comparaison de la somme des indices de similarité (SUB).png', dpi= 300)
# Out:
# /tmp/ipykernel_68003/1235394149.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Occurrences'][i] = df2['Occurrences'][i]/df2['Occurrences'].sum()
# /tmp/ipykernel_68003/1235394149.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Occurrences'][i] = df['Occurrences'][i]/df['Occurrences'].sum()
# /tmp/ipykernel_68003/3244870969.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
