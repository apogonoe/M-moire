# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import distance
from collections import Counter

# %matplotlib inline

# %%
def from_csv_to_dffreq_VBE(path):
    
    import pandas as pd
    
    
    names = ['texte','pre','lemma','post']
    df = pd.read_csv(path, sep=',', header = 0, encoding='UTF-8', names=names)
    df = df[['pre','post']]
    
    liste_1 = df['pre'].str.split((' ')).tolist()
    for i in range(len(liste_1)):
        liste_1[i] = liste_1[i][-5:]
    liste_2 = df['post'].str.split((' ')).tolist()
    for i in range(len(liste_2)):
        liste_2[i] = liste_2[i][:5]
    
    liste_SUB = []
    for item in liste_1:
        for i in item:
            if i.endswith('/VBE'):
                liste_SUB.append(i)
    for item in liste_2:
        for i in item:
            if i.endswith('/VBE'):
                liste_SUB.append(i)
                
    list_tuples_SUB = Counter(liste_SUB).most_common()
    
    dictionnaire_vide = dict(list_tuples_SUB)
    
    dict_items = dictionnaire_vide.items()
    
    first_hundred = list(dict_items)[:100]
    
    dico_final = dict(first_hundred)
    
    a = list(dico_final.keys())
    b = list(dico_final.values())

    df_final = pd.DataFrame(a,b)
    df_final.reset_index(inplace=True)
    df_final.columns = ["Occurrences","lemma"]  
    
    df_final['lemma'] = df_final['lemma'].str.split('/').str[0]
    
    return df_final

# %%
def from_csv_to_dffreq_SUB(path):
    
    import pandas as pd
    
    df = pd.read_csv(path, sep=',', header = 0, encoding='UTF-8')
    #df.columns = ['texte','pre','lemma','post']
    df = df[['pre','post']]
    
    liste_1 = df['pre'].str.split((' ')).tolist()
    for i in range(len(liste_1)):
        liste_1[i] = liste_1[i][-5:]
    liste_2 = df['post'].str.split((' ')).tolist()
    for i in range(len(liste_2)):
        liste_2[i] = liste_2[i][:5]
    
    liste_SUB = []
    for item in liste_1:
        for i in item:
            if i.endswith('/SUB'):
                liste_SUB.append(i)
    for item in liste_2:
        for i in item:
            if i.endswith('/SUB'):
                liste_SUB.append(i)
                
    list_tuples_SUB = Counter(liste_SUB).most_common()
    
    dictionnaire_vide = dict(list_tuples_SUB)
    
    dict_items = dictionnaire_vide.items()
    
    first_hundred = list(dict_items)[:100]
    
    dico_final = dict(first_hundred)
    
    a = list(dico_final.keys())
    b = list(dico_final.values())

    df_final = pd.DataFrame(a,b)
    df_final.reset_index(inplace=True)
    df_final.columns = ["Occurrences","lemma"]  
    
    df_final['lemma'] = df_final['lemma'].str.split('/').str[0]
    
    return df_final

# %%
def from_csv_to_dffreq_QLF(path):
    
    import pandas as pd
    
    df = pd.read_csv(path, sep=',', header = 4, encoding='UTF-8')
    df.columns = ['texte','pre','lemma','post']
    df = df[['pre','post']]
    
    liste_1 = df['pre'].str.split((' ')).tolist()
    for i in range(len(liste_1)):
        liste_1[i] = liste_1[i][-5:]
    liste_2 = df['post'].str.split((' ')).tolist()
    for i in range(len(liste_2)):
        liste_2[i] = liste_2[i][:5]
    
    liste_SUB = []
    for item in liste_1:
        for i in item:
            if i.endswith('/QLF'):
                liste_SUB.append(i)
    for item in liste_2:
        for i in item:
            if i.endswith('/QLF'):
                liste_SUB.append(i)
                
    list_tuples_SUB = Counter(liste_SUB).most_common()
    
    dictionnaire_vide = dict(list_tuples_SUB)
    
    dict_items = dictionnaire_vide.items()
    
    first_hundred = list(dict_items)[:100]
    
    dico_final = dict(first_hundred)
    
    a = list(dico_final.keys())
    b = list(dico_final.values())

    df_final = pd.DataFrame(a,b)
    df_final.reset_index(inplace=True)
    df_final.columns = ["Occurrences","lemma"]  
    
    df_final['lemma'] = df_final['lemma'].str.split('/').str[0]
    
    return df_final

# %%
df1 = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Lemma_clean/800-849.csv', header=0,sep=',')

# %%
df1
# Out:
#      Unnamed: 0                                                pre  \
# 0             0  meus/QLF  aliquis/PRO  deus/SUB  confero/VBE <...
# 1             3  ipse2/PRO  hic3/PRO  --/VBE  apostolicus/QLF  ...
# 2             4  ut/CON  aliquis/PRO  de/PRE  res/SUB  meus/QLF...
# 3             5  interim/ADV  uero1/ADV  ego/PRO  ipse2/PRO  du...
# 4             6  aliquis/PRO  de/PRE  res/SUB  meus/QLF  propri...
# ..          ...                                                ...
# 627         703  nomen/SUB  feliciter/ADV  --/NAM </s><s> in/PR...
# 628         704  ad/PRE  causa2/SUB  audio/VBE  uel/CON  fredus...
# 629         705  meus/QLF  --/VBE  sum/VBE  suprascriptus/QLF  ...
# 630         706  <s> si/CON  sospes/QLF  ad/PRE  proprius1/QLF ...
# 631         707  solidus2/SUB </s><s> et/CON  qui2/PRO  in/PRE ...
#
#             lemma                                               post  \
# 0     seruus2/SUB   ancilla/SUB  --/QLF  ruro/VBE  campus/SUB  si...
# ...

# %%
df = from_csv_to_dffreq_QLF('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Molina/Lemma/800-849.csv')

# %%
df.to_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Molina/Cooccurrences/QLF/800-849.csv')

# %%
df2 = from_csv_to_dffreq_SUB('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Lemma_clean/800-849.csv')

# %%
df2.to_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurences/SUB/800-849.csv')

# %%
df3 = from_csv_to_dffreq_VBE('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Lemma_clean/800-849.csv')

# %%
df3.to_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Cooccurences/VBE/800-849.csv')
