# %%
import pandas as pd

# %%
colonnes = ['indice','pre','lemma','post']
df = pd.read_csv('/home/noe/Documents/Master_2/Mémoire/SketchEngineExport/lemmes_servitude/Seruus/Lemma_brut/Without_tags/seruus_lemme.csv', sep=',', header=4, names=colonnes, encoding ='UTF-8')
df['new'] = df['pre'] + (' ') + df['lemma']+ (' ') + df['post']
df['new'] = df['new'].str.lower()
df['drop'] = df['new'].str.find('seruus2 seruus2 deus')
df = df[df['drop'] == -1]
df
# Out:
#                                 indice  \
# 0                   0800_passau_224441
# 3          0800_pflugk-harttung_236150
# 4                0800_saintgall_224984
# 5                0800_saintgall_224984
# 6                  0800_stclaude_53057
# ...                                ...
# 34227                   1299_wub_59832
# 34228             9999_hersfeld_229038
# 34229    9999_marmoutiermanceau_255656
# 34230  9999_marmoutiervendomois_256306
# 34231  9999_marmoutiervendomois_256373
#
#                                                      pre    lemma  \
# 0      meus aliquis deus confero </s><s> trado itaque...  seruus2
# 3      ipse2 hic3 -- apostolicus auctoritas priuilegi...  seruus2
# 4      ut aliquis de res meus ad monasterium sanctus1...  seruus2
# 5      interim uero1 ego ipse2 dum aduiuo inde soluo ...  seruus2
# 6      aliquis de res meus proprius1 qui2 sum sino in...  seruus2
# ...                                                  ...      ...
# 34227  infigo non habeo </s><s> nos denique hic3 dubi...  seruus2
# 34228  <s> in -- hoba 2 </s><s> in -- hoba 3 mansus 2...  seruus2
# 34229  terra quantum in uinea ille2 sum do is2 et suu...  seruus2
# 34230  de -- -- -- -- super -- de -- debeo si qui2 su...  seruus2
# 34231  adnoto contineo per ordo nam magnus de -- -- p...  seruus2
#
#                                                     post  \
# 0      ancilla -- ruro campus silua aqua qui2 decursu...
# 3      ancilla uilla reditus possideo uel deinceps1 a...
# 4      meus nomen -- cum1 hoba suus in uilla qui2 uoc...
# 5      reditio sum post2 obitus uero1 meus ad ipse2 m...
# 6      deus ibi manens1 hic3 res omnis tempus posside...
# ...                                                  ...
# 34227  noster cenobium curia et mansus et duo -- cum1...
# 34228  2 litus1 ixion et sum per totus hoba -- mansus...
# 34229  uel collibertus nullus habeo </s><s> facio eti...
# 34230  quondam et forestarius2 comes -- calumnia infe...
# 34231  -- -- -- </s><s> notitia -- de -- -- </s><s> n...
#
#                                                      new  drop
# 0      meus aliquis deus confero </s><s> trado itaque...    -1
# 3      ipse2 hic3 -- apostolicus auctoritas priuilegi...    -1
# 4      ut aliquis de res meus ad monasterium sanctus1...    -1
# 5      interim uero1 ego ipse2 dum aduiuo inde soluo ...    -1
# 6      aliquis de res meus proprius1 qui2 sum sino in...    -1
# ...                                                  ...   ...
# 34227  infigo non habeo </s><s> nos denique hic3 dubi...    -1
# 34228  <s> in -- hoba 2 </s><s> in -- hoba 3 mansus 2...    -1
# 34229  terra quantum in uinea ille2 sum do is2 et suu...    -1
# 34230  de -- -- -- -- super -- de -- debeo si qui2 su...    -1
# 34231  adnoto contineo per ordo nam magnus de -- -- p...    -1
#
# [7223 rows x 6 columns]
